# %%
from google.colab import drive
import pandas as pd
import seaborn as sns
import numpy as np
drive.mount("/mnt")
# Out:
# Mounted at /mnt

# %%
data1 = pd.read_csv('/issues1.csv', index_col=0)
data1
# Out:
#                                          Id  Channel       category  \
# 0      8c910188-c387-4a1b-8d90-24379ec8c047  Inbound        Returns
# 1      99d5ee06-8d2a-4754-bd17-ed235c70bf33  Inbound        Returns
# 2      336020c5-dc97-488f-8f16-ed33ed04e5fc  Inbound        Returns
# 3      22c5643c-3d54-487c-8863-c57e198a70be  Inbound        Returns
# 4      abd330a8-f3e2-4b7a-b14a-4ed35c4ec023  Inbound        Returns
# ...                                     ...      ...            ...
# 28420  64538432-9040-4fe2-9c50-da8f68358050  Outcall  Order Related
# 28421  3468bfda-b5c8-4795-bf13-ce3bd343d382  Inbound  Order Related
# 28422  83bcf710-7373-4572-a740-63c3a04b9fda  Inbound        Returns
# 28423  b959d639-c2c8-43c8-8edb-0063c273adc8  Inbound        Returns
# 28424  8dc802d1-7932-4992-91e7-66b2a4748fc0  Inbound        Returns
#
#                  Sub-category  \
# 0      Reverse Pickup Enquiry
# 1              Return request
# 2                     Damaged
# 3             Fraudulent User
# 4             Fraudulent User
# ...                       ...
# 28420    Order status enquiry
# 28421                 Delayed
# 28422          Return request
# 28423  Reverse Pickup Enquiry
# 28424  Reverse Pickup Enquiry
#
#                                         Customer Remarks  \
# 0                                            Very happy
# 1           Thoda jalfi replacement approve kijiye mera
# 2      Technician not visit the RO and without visit ...
# 3        madam ne mera problem solve kar Diya hai . t...
# 4                                 Gjjjzjxgxteuhxgxe5xhxh
# ...                                                  ...
# 28420                                                  G
# 28421                                  My all doubt soul
# 28422                   Please don't send wrong product
# 28423                                      Ekadam bakwas
# 28424                             Thanks for supporting
#
#                                    Order_id Issue_reported_Date  \
# 0                                       NaN    04/08/2023 19:10
# 1      89e6448f-9a48-4892-a09c-b47e0d8a87fe    18/08/2023 09:11
# 2      15476f9a-35cc-4f33-ae33-8d9cd6ecb1a6    22/08/2023 07:15
# 3                                       NaN    14/08/2023 09:21
# 4                                       NaN    03/08/2023 08:18
# ...                                     ...                 ...
# 28420  3215dbf5-47bf-4843-abee-f6eb36a808a7    24/08/2023 18:21
# 28421  3d8c15db-c338-4ead-b082-ebf2180df920    28/08/2023 13:16
# 28422                                   NaN    16/08/2023 17:37
# 28423  aba1a75d-06c7-4523-9125-1e98aaa3842a    07/08/2023 10:42
# 28424  c8db4a4e-1f58-4e2c-84a2-34f0c57a2201    21/08/2023 16:49
#
#       Issue_responded_Date Survey_response_Date    Agent_name  CSAT Score
# 0         04/08/2023 19:13            04-Aug-23  J. Blackwell           1
# 1         18/08/2023 09:18            18-Aug-23     M. Wilson           4
# 2         22/08/2023 08:15            22-Aug-23      A. Smith           5
# 3         14/08/2023 09:27            14-Aug-23      A. Berry           5
# 4         03/08/2023 08:23            03-Aug-23     S. Taylor           5
# ...                    ...                  ...           ...         ...
# 28420     24/08/2023 21:44            24-Aug-23     J. Bailey           5
# 28421     28/08/2023 00:00            28-Aug-23      A. Clark           4
# 28422     16/08/2023 17:43            16-Aug-23   J. Reynolds           5
# 28423     07/08/2023 10:57            07-Aug-23     G. Campos           1
# 28424     21/08/2023 16:51            21-Aug-23       D. Ball           5
#
# [28425 rows x 11 columns]

# %%
data2 = pd.read_csv('/issues2.csv', index_col=0)
data2
# Out:
#                                          Id channel_name           category  \
# 0      6ba211fe-7643-4998-a7f7-cf34e5a4322c      Inbound      Order Related
# 1      acef2550-cdd7-4e6a-b5b8-6d9627da9549      Inbound       Cancellation
# 2      46d012ec-cb21-40ce-afe1-5fe78905250a      Inbound            Returns
# 3      1671c7fa-e527-4a05-8f1f-9a865dad9778      Outcall       Cancellation
# 4      6e1923bd-de16-462b-a3ec-c60fb0ffe194      Inbound     Refund Related
# ...                                     ...          ...                ...
# 44334  0e5c4973-24bc-4d7d-9eb4-54c868721109      Inbound    Product Queries
# 44335  2fb101c6-3f7d-46ea-a0cb-c6a7b085d1d1      Inbound  Shopzilla Related
# 44336  cbb0d288-a7d7-40b8-a52a-2896ba4d7ce2      Inbound            Returns
# 44337  8de9d211-cf76-4447-962c-0517b922b548      Inbound            Returns
# 44338  ebc56b78-e5c4-4f2d-939d-dc4c70feae71      Inbound            Returns
#
#                        Sub-category                              Order_id  \
# 0                           Delayed  2dab4a7a-baf0-49f9-9d84-c8acdb4a11db
# 1                        Not Needed  5993a1f0-570d-4c82-95d9-6cc56c78043e
# 2                    Return request  b64f579f-d913-4e85-978f-d0f6de902c3f
# 3                        Not Needed  b754581f-a2a4-4ef2-abb1-aca09ac1a89c
# 4                    Refund Enquiry  a1c40c79-e7a6-4faa-b948-0a32c3e3576a
# ...                             ...                                   ...
# 44334  Product Specific Information  74ca7f8d-9c52-4902-b981-6fb6a5932c72
# 44335               General Enquiry  7cc638a3-6273-4e2a-86ea-60436df6c0b9
# 44336                Return request  af616b51-6739-48cd-a8f5-4f04b5eb8f79
# 44337       Service Centres Related  95de5b8a-145e-4282-a631-ddec3017d912
# 44338               Fraudulent User  d0755ce6-a553-4fa6-8a71-b9f5478338d1
#
#                    Reported at             Responded at Survey responded at  \
# 0      21 08 2023, 09:01:00 PM  21 08 2023, 09:04:00 PM          21 08 2023
# 1      18 08 2023, 09:20:00 PM  18 08 2023, 09:20:00 PM          18 08 2023
# 2      24 08 2023, 09:57:00 PM  24 08 2023, 09:58:00 PM          24 08 2023
# 3      28 08 2023, 11:38:00 PM  29 08 2023, 05:55:00 AM          29 08 2023
# 4      30 08 2023, 11:03:00 AM  30 08 2023, 11:04:00 AM          30 08 2023
# ...                        ...                      ...                 ...
# 44334  08 08 2023, 12:13:00 PM  08 08 2023, 06:44:00 PM          08 08 2023
# 44335  22 08 2023, 07:37:00 PM  22 08 2023, 08:21:00 PM          22 08 2023
# 44336  08 12 2023, 04:39:00 PM  12 08 2023, 04:43:00 PM          12 08 2023
# 44337  27 08 2023, 08:19:00 AM  27 08 2023, 08:21:00 AM          27 08 2023
# 44338  13 08 2023, 12:25:00 PM  13 08 2023, 12:30:00 PM          13 08 2023
#
#          Agent_name  CSAT Score
# 0      A. Rodriguez           5
# 1            R. Lee           5
# 2        S. Douglas           5
# 3          T. Adams           5
# 4           L. Beck           5
# ...             ...         ...
# 44334      J. Kelly           5
# 44335     S. Nelson           5
# 44336      D. Terry           5
# 44337      G. Jones           5
# 44338       T. Holt           5
#
# [44339 rows x 10 columns]

# %%
data3 = pd.read_csv('/issues4.csv', index_col=0)
data3.head()
# Out:
#                               Unique id channel_name        category  \
# 0  3350ccee-ead7-40fa-80c6-cc7b5e6e345a      Inbound         Returns
# 1  4a88df6e-aafb-477a-bd8e-63ffc34c1a43      Inbound         Returns
# 2  7b5dbea2-2370-490a-8fef-4c5f7c52a4cc      Inbound         Returns
# 3  c6d4401e-a4ef-4de0-af68-a8755b928f5f      Inbound  Refund Related
# 4  423bd17e-e944-4f6e-beff-9c97fa325d9e      Inbound         Returns
#
#              Sub-category               Issue_reported at  \
# 0  Reverse Pickup Enquiry    August 27, 2023, 08:28:00 AM
# 1                   Wrong  December 08, 2023, 03:04:00 PM
# 2  Reverse Pickup Enquiry    August 13, 2023, 12:45:00 PM
# 3          Refund Enquiry      June 08, 2023, 06:07:00 PM
# 4  Reverse Pickup Enquiry     April 08, 2023, 10:05:00 PM
#
#                 issue_responded          Survey_response_Date  \
# 0  August 27, 2023, 08:29:00 AM  August 27, 2023, 12:00:00 AM
# 1  August 12, 2023, 03:19:00 PM  August 12, 2023, 12:00:00 AM
# 2  August 13, 2023, 01:02:00 PM  August 13, 2023, 12:00:00 AM
# 3  August 06, 2023, 06:08:00 PM  August 06, 2023, 12:00:00 AM
# 4  August 04, 2023, 10:08:00 PM  August 04, 2023, 12:00:00 AM
#
#                Agent  CSAT Score
# 0        Terry Young           5
# 1         Brenda Cox           4
# 2      Brian Mcguire           5
# 3  Dr. Heather Lewis           5
# 4      Kristin Adams           5

# %%
data1.shape, data2.shape, data3.shape
# Out:
# ((28425, 11), (44339, 10), (13143, 9))

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 28425 entries, 0 to 28424
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Id                    28425 non-null  object
#  1   Channel               28425 non-null  object
#  2   category              28425 non-null  object
#  3   Sub-category          28425 non-null  object
#  4   Customer Remarks      28425 non-null  object
#  5   Order_id              22389 non-null  object
#  6   Issue_reported_Date   28425 non-null  object
#  7   Issue_responded_Date  28425 non-null  object
#  8   Survey_response_Date  28425 non-null  object
#  9   Agent_name            28425 non-null  object
#  10  CSAT Score            28425 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 3.6+ MB

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 44339 entries, 0 to 44338
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   44339 non-null  object
#  1   channel_name         44339 non-null  object
#  2   category             44339 non-null  object
#  3   Sub-category         44339 non-null  object
#  4   Order_id             44272 non-null  object
#  5   Reported at          44339 non-null  object
#  6   Responded at         44339 non-null  object
#  7   Survey responded at  44339 non-null  object
#  8   Agent_name           44339 non-null  object
#  9   CSAT Score           44339 non-null  int64
# dtypes: int64(1), object(9)
# memory usage: 4.7+ MB

# %%
data2 = data2.rename(columns={
    'channel_name': 'Channel',
    'Reported at': 'Issue_reported_Date',
    'Responded at': 'Issue_responded_Date',
    'Survey responded at': 'Survey_response_Date',
})

# %%
data2['Issue_reported_Date'] = pd.to_datetime(data2['Issue_reported_Date'])
data2['Issue_responded_Date'] = pd.to_datetime(data2['Issue_responded_Date'])
data2['Survey_response_Date'] = pd.to_datetime(data2['Survey_response_Date'], format='%d %m %Y')
# Out:
# <ipython-input-9-a5e2289ea512>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data2['Issue_reported_Date'] = pd.to_datetime(data2['Issue_reported_Date'])
# <ipython-input-9-a5e2289ea512>:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data2['Issue_responded_Date'] = pd.to_datetime(data2['Issue_responded_Date'])

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 44339 entries, 0 to 44338
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Id                    44339 non-null  object
#  1   Channel               44339 non-null  object
#  2   category              44339 non-null  object
#  3   Sub-category          44339 non-null  object
#  4   Order_id              44272 non-null  object
#  5   Issue_reported_Date   44339 non-null  datetime64[ns]
#  6   Issue_responded_Date  44339 non-null  datetime64[ns]
#  7   Survey_response_Date  44339 non-null  datetime64[ns]
#  8   Agent_name            44339 non-null  object
#  9   CSAT Score            44339 non-null  int64
# dtypes: datetime64[ns](3), int64(1), object(6)
# memory usage: 4.7+ MB

# %%
data2
# Out:
#                                          Id  Channel           category  \
# 0      6ba211fe-7643-4998-a7f7-cf34e5a4322c  Inbound      Order Related
# 1      acef2550-cdd7-4e6a-b5b8-6d9627da9549  Inbound       Cancellation
# 2      46d012ec-cb21-40ce-afe1-5fe78905250a  Inbound            Returns
# 3      1671c7fa-e527-4a05-8f1f-9a865dad9778  Outcall       Cancellation
# 4      6e1923bd-de16-462b-a3ec-c60fb0ffe194  Inbound     Refund Related
# ...                                     ...      ...                ...
# 44334  0e5c4973-24bc-4d7d-9eb4-54c868721109  Inbound    Product Queries
# 44335  2fb101c6-3f7d-46ea-a0cb-c6a7b085d1d1  Inbound  Shopzilla Related
# 44336  cbb0d288-a7d7-40b8-a52a-2896ba4d7ce2  Inbound            Returns
# 44337  8de9d211-cf76-4447-962c-0517b922b548  Inbound            Returns
# 44338  ebc56b78-e5c4-4f2d-939d-dc4c70feae71  Inbound            Returns
#
#                        Sub-category                              Order_id  \
# 0                           Delayed  2dab4a7a-baf0-49f9-9d84-c8acdb4a11db
# 1                        Not Needed  5993a1f0-570d-4c82-95d9-6cc56c78043e
# 2                    Return request  b64f579f-d913-4e85-978f-d0f6de902c3f
# 3                        Not Needed  b754581f-a2a4-4ef2-abb1-aca09ac1a89c
# 4                    Refund Enquiry  a1c40c79-e7a6-4faa-b948-0a32c3e3576a
# ...                             ...                                   ...
# 44334  Product Specific Information  74ca7f8d-9c52-4902-b981-6fb6a5932c72
# 44335               General Enquiry  7cc638a3-6273-4e2a-86ea-60436df6c0b9
# 44336                Return request  af616b51-6739-48cd-a8f5-4f04b5eb8f79
# 44337       Service Centres Related  95de5b8a-145e-4282-a631-ddec3017d912
# 44338               Fraudulent User  d0755ce6-a553-4fa6-8a71-b9f5478338d1
#
#       Issue_reported_Date Issue_responded_Date Survey_response_Date  \
# 0     2023-08-21 21:01:00  2023-08-21 21:04:00           2023-08-21
# 1     2023-08-18 21:20:00  2023-08-18 21:20:00           2023-08-18
# 2     2023-08-24 21:57:00  2023-08-24 21:58:00           2023-08-24
# 3     2023-08-28 23:38:00  2023-08-29 05:55:00           2023-08-29
# 4     2023-08-30 11:03:00  2023-08-30 11:04:00           2023-08-30
# ...                   ...                  ...                  ...
# 44334 2023-08-08 12:13:00  2023-08-08 18:44:00           2023-08-08
# 44335 2023-08-22 19:37:00  2023-08-22 20:21:00           2023-08-22
# 44336 2023-08-12 16:39:00  2023-12-08 16:43:00           2023-08-12
# 44337 2023-08-27 08:19:00  2023-08-27 08:21:00           2023-08-27
# 44338 2023-08-13 12:25:00  2023-08-13 12:30:00           2023-08-13
#
#          Agent_name  CSAT Score
# 0      A. Rodriguez           5
# 1            R. Lee           5
# 2        S. Douglas           5
# 3          T. Adams           5
# 4           L. Beck           5
# ...             ...         ...
# 44334      J. Kelly           5
# 44335     S. Nelson           5
# 44336      D. Terry           5
# 44337      G. Jones           5
# 44338       T. Holt           5
#
# [44339 rows x 10 columns]

# %%
data1['Issue_reported_Date'] = pd.to_datetime(data1['Issue_reported_Date'], dayfirst=True)
data1['Issue_responded_Date'] = pd.to_datetime(data1['Issue_responded_Date'], dayfirst=True)
data1['Survey_response_Date'] = pd.to_datetime(data1['Survey_response_Date'], format='%d-%b-%y')
data1
# Out:
#                                          Id  Channel       category  \
# 0      8c910188-c387-4a1b-8d90-24379ec8c047  Inbound        Returns
# 1      99d5ee06-8d2a-4754-bd17-ed235c70bf33  Inbound        Returns
# 2      336020c5-dc97-488f-8f16-ed33ed04e5fc  Inbound        Returns
# 3      22c5643c-3d54-487c-8863-c57e198a70be  Inbound        Returns
# 4      abd330a8-f3e2-4b7a-b14a-4ed35c4ec023  Inbound        Returns
# ...                                     ...      ...            ...
# 28420  64538432-9040-4fe2-9c50-da8f68358050  Outcall  Order Related
# 28421  3468bfda-b5c8-4795-bf13-ce3bd343d382  Inbound  Order Related
# 28422  83bcf710-7373-4572-a740-63c3a04b9fda  Inbound        Returns
# 28423  b959d639-c2c8-43c8-8edb-0063c273adc8  Inbound        Returns
# 28424  8dc802d1-7932-4992-91e7-66b2a4748fc0  Inbound        Returns
#
#                  Sub-category  \
# 0      Reverse Pickup Enquiry
# 1              Return request
# 2                     Damaged
# 3             Fraudulent User
# 4             Fraudulent User
# ...                       ...
# 28420    Order status enquiry
# 28421                 Delayed
# 28422          Return request
# 28423  Reverse Pickup Enquiry
# 28424  Reverse Pickup Enquiry
#
#                                         Customer Remarks  \
# 0                                            Very happy
# 1           Thoda jalfi replacement approve kijiye mera
# 2      Technician not visit the RO and without visit ...
# 3        madam ne mera problem solve kar Diya hai . t...
# 4                                 Gjjjzjxgxteuhxgxe5xhxh
# ...                                                  ...
# 28420                                                  G
# 28421                                  My all doubt soul
# 28422                   Please don't send wrong product
# 28423                                      Ekadam bakwas
# 28424                             Thanks for supporting
#
#                                    Order_id Issue_reported_Date  \
# 0                                       NaN 2023-08-04 19:10:00
# 1      89e6448f-9a48-4892-a09c-b47e0d8a87fe 2023-08-18 09:11:00
# 2      15476f9a-35cc-4f33-ae33-8d9cd6ecb1a6 2023-08-22 07:15:00
# 3                                       NaN 2023-08-14 09:21:00
# 4                                       NaN 2023-08-03 08:18:00
# ...                                     ...                 ...
# 28420  3215dbf5-47bf-4843-abee-f6eb36a808a7 2023-08-24 18:21:00
# 28421  3d8c15db-c338-4ead-b082-ebf2180df920 2023-08-28 13:16:00
# 28422                                   NaN 2023-08-16 17:37:00
# 28423  aba1a75d-06c7-4523-9125-1e98aaa3842a 2023-08-07 10:42:00
# 28424  c8db4a4e-1f58-4e2c-84a2-34f0c57a2201 2023-08-21 16:49:00
#
#       Issue_responded_Date Survey_response_Date    Agent_name  CSAT Score
# 0      2023-08-04 19:13:00           2023-08-04  J. Blackwell           1
# 1      2023-08-18 09:18:00           2023-08-18     M. Wilson           4
# 2      2023-08-22 08:15:00           2023-08-22      A. Smith           5
# 3      2023-08-14 09:27:00           2023-08-14      A. Berry           5
# 4      2023-08-03 08:23:00           2023-08-03     S. Taylor           5
# ...                    ...                  ...           ...         ...
# 28420  2023-08-24 21:44:00           2023-08-24     J. Bailey           5
# 28421  2023-08-28 00:00:00           2023-08-28      A. Clark           4
# 28422  2023-08-16 17:43:00           2023-08-16   J. Reynolds           5
# 28423  2023-08-07 10:57:00           2023-08-07     G. Campos           1
# 28424  2023-08-21 16:51:00           2023-08-21       D. Ball           5
#
# [28425 rows x 11 columns]

# %%
data_12 = pd.concat([data1, data2])
data_12
# Out:
#                                          Id  Channel           category  \
# 0      8c910188-c387-4a1b-8d90-24379ec8c047  Inbound            Returns
# 1      99d5ee06-8d2a-4754-bd17-ed235c70bf33  Inbound            Returns
# 2      336020c5-dc97-488f-8f16-ed33ed04e5fc  Inbound            Returns
# 3      22c5643c-3d54-487c-8863-c57e198a70be  Inbound            Returns
# 4      abd330a8-f3e2-4b7a-b14a-4ed35c4ec023  Inbound            Returns
# ...                                     ...      ...                ...
# 44334  0e5c4973-24bc-4d7d-9eb4-54c868721109  Inbound    Product Queries
# 44335  2fb101c6-3f7d-46ea-a0cb-c6a7b085d1d1  Inbound  Shopzilla Related
# 44336  cbb0d288-a7d7-40b8-a52a-2896ba4d7ce2  Inbound            Returns
# 44337  8de9d211-cf76-4447-962c-0517b922b548  Inbound            Returns
# 44338  ebc56b78-e5c4-4f2d-939d-dc4c70feae71  Inbound            Returns
#
#                        Sub-category  \
# 0            Reverse Pickup Enquiry
# 1                    Return request
# 2                           Damaged
# 3                   Fraudulent User
# 4                   Fraudulent User
# ...                             ...
# 44334  Product Specific Information
# 44335               General Enquiry
# 44336                Return request
# 44337       Service Centres Related
# 44338               Fraudulent User
#
#                                         Customer Remarks  \
# 0                                            Very happy
# 1           Thoda jalfi replacement approve kijiye mera
# 2      Technician not visit the RO and without visit ...
# 3        madam ne mera problem solve kar Diya hai . t...
# 4                                 Gjjjzjxgxteuhxgxe5xhxh
# ...                                                  ...
# 44334                                                NaN
# 44335                                                NaN
# 44336                                                NaN
# 44337                                                NaN
# 44338                                                NaN
#
#                                    Order_id Issue_reported_Date  \
# 0                                       NaN 2023-08-04 19:10:00
# 1      89e6448f-9a48-4892-a09c-b47e0d8a87fe 2023-08-18 09:11:00
# 2      15476f9a-35cc-4f33-ae33-8d9cd6ecb1a6 2023-08-22 07:15:00
# 3                                       NaN 2023-08-14 09:21:00
# 4                                       NaN 2023-08-03 08:18:00
# ...                                     ...                 ...
# 44334  74ca7f8d-9c52-4902-b981-6fb6a5932c72 2023-08-08 12:13:00
# 44335  7cc638a3-6273-4e2a-86ea-60436df6c0b9 2023-08-22 19:37:00
# 44336  af616b51-6739-48cd-a8f5-4f04b5eb8f79 2023-08-12 16:39:00
# 44337  95de5b8a-145e-4282-a631-ddec3017d912 2023-08-27 08:19:00
# 44338  d0755ce6-a553-4fa6-8a71-b9f5478338d1 2023-08-13 12:25:00
#
#       Issue_responded_Date Survey_response_Date    Agent_name  CSAT Score
# 0      2023-08-04 19:13:00           2023-08-04  J. Blackwell           1
# 1      2023-08-18 09:18:00           2023-08-18     M. Wilson           4
# 2      2023-08-22 08:15:00           2023-08-22      A. Smith           5
# 3      2023-08-14 09:27:00           2023-08-14      A. Berry           5
# 4      2023-08-03 08:23:00           2023-08-03     S. Taylor           5
# ...                    ...                  ...           ...         ...
# 44334  2023-08-08 18:44:00           2023-08-08      J. Kelly           5
# 44335  2023-08-22 20:21:00           2023-08-22     S. Nelson           5
# 44336  2023-12-08 16:43:00           2023-08-12      D. Terry           5
# 44337  2023-08-27 08:21:00           2023-08-27      G. Jones           5
# 44338  2023-08-13 12:30:00           2023-08-13       T. Holt           5
#
# [72764 rows x 11 columns]

# %%
data_12.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 72764 entries, 0 to 44338
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Id                    72764 non-null  object
#  1   Channel               72764 non-null  object
#  2   category              72764 non-null  object
#  3   Sub-category          72764 non-null  object
#  4   Customer Remarks      28425 non-null  object
#  5   Order_id              66661 non-null  object
#  6   Issue_reported_Date   72764 non-null  datetime64[ns]
#  7   Issue_responded_Date  72764 non-null  datetime64[ns]
#  8   Survey_response_Date  72764 non-null  datetime64[ns]
#  9   Agent_name            72764 non-null  object
#  10  CSAT Score            72764 non-null  int64
# dtypes: datetime64[ns](3), int64(1), object(7)
# memory usage: 6.7+ MB

# %%
data3 = data3.rename(columns={
    'Unique id': 'Id',
    'channel_name': 'Channel',
    'Issue_reported at': 'Issue_reported_Date',
    'issue_responded': 'Issue_responded_Date',
    'Survey responded at': 'Survey_response_Date',
    'Agent': 'Agent_name'
})

# %%
data3['Issue_reported_Date'] = pd.to_datetime(data3['Issue_reported_Date'])
data3['Issue_responded_Date'] = pd.to_datetime(data3['Issue_responded_Date'])
data3['Survey_response_Date'] = pd.to_datetime(data3['Survey_response_Date'])
# Out:
# <ipython-input-16-a84f6c2ad651>:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data3['Survey_response_Date'] = pd.to_datetime(data3['Survey_response_Date'])

# %%
data_123 = pd.concat([data_12, data3])
data_123
# Out:
#                                          Id  Channel          category  \
# 0      8c910188-c387-4a1b-8d90-24379ec8c047  Inbound           Returns
# 1      99d5ee06-8d2a-4754-bd17-ed235c70bf33  Inbound           Returns
# 2      336020c5-dc97-488f-8f16-ed33ed04e5fc  Inbound           Returns
# 3      22c5643c-3d54-487c-8863-c57e198a70be  Inbound           Returns
# 4      abd330a8-f3e2-4b7a-b14a-4ed35c4ec023  Inbound           Returns
# ...                                     ...      ...               ...
# 13138  ea09d98a-63d4-4143-8035-0e92c468baca  Inbound  Payments related
# 13139  ebf0a860-c06d-4a10-a631-43787004d7dc  Inbound           Returns
# 13140  e5bd9747-3a7e-4c3e-8972-670fa338b4c8  Inbound     Order Related
# 13141  13bfa4ab-d0b2-455d-b5d4-dbbb8c4de450  Inbound           Returns
# 13142  eb6ef5e0-6cac-4209-8b0a-d35a62f85234  Inbound           Returns
#
#                  Sub-category  \
# 0      Reverse Pickup Enquiry
# 1              Return request
# 2                     Damaged
# 3             Fraudulent User
# 4             Fraudulent User
# ...                       ...
# 13138   Online Payment Issues
# 13139  Reverse Pickup Enquiry
# 13140       Priority delivery
# 13141  Reverse Pickup Enquiry
# 13142  Reverse Pickup Enquiry
#
#                                         Customer Remarks  \
# 0                                            Very happy
# 1           Thoda jalfi replacement approve kijiye mera
# 2      Technician not visit the RO and without visit ...
# 3        madam ne mera problem solve kar Diya hai . t...
# 4                                 Gjjjzjxgxteuhxgxe5xhxh
# ...                                                  ...
# 13138                                                NaN
# 13139                                                NaN
# 13140                                                NaN
# 13141                                                NaN
# 13142                                                NaN
#
#                                    Order_id Issue_reported_Date  \
# 0                                       NaN 2023-08-04 19:10:00
# 1      89e6448f-9a48-4892-a09c-b47e0d8a87fe 2023-08-18 09:11:00
# 2      15476f9a-35cc-4f33-ae33-8d9cd6ecb1a6 2023-08-22 07:15:00
# 3                                       NaN 2023-08-14 09:21:00
# 4                                       NaN 2023-08-03 08:18:00
# ...                                     ...                 ...
# 13138                                   NaN 2023-08-16 15:10:00
# 13139                                   NaN 2023-08-15 16:16:00
# 13140                                   NaN 2023-08-27 16:23:00
# 13141                                   NaN 2023-03-08 14:51:00
# 13142                                   NaN 2023-08-14 08:35:00
#
#       Issue_responded_Date Survey_response_Date        Agent_name  CSAT Score
# 0      2023-08-04 19:13:00           2023-08-04      J. Blackwell           1
# 1      2023-08-18 09:18:00           2023-08-18         M. Wilson           4
# 2      2023-08-22 08:15:00           2023-08-22          A. Smith           5
# 3      2023-08-14 09:27:00           2023-08-14          A. Berry           5
# 4      2023-08-03 08:23:00           2023-08-03         S. Taylor           5
# ...                    ...                  ...               ...         ...
# 13138  2023-08-16 15:12:00           2023-08-16     Karen Schultz           5
# 13139  2023-08-15 16:20:00           2023-08-15     Brandon Frost           5
# 13140  2023-08-27 16:25:00           2023-08-27     Deanna Wright           1
# 13141  2023-08-03 15:08:00           2023-08-03    Monica Edwards           5
# 13142  2023-08-14 08:41:00           2023-08-14  Carol Washington           2
#
# [85907 rows x 11 columns]

# %%
data3['Agent_name'] = data3['Agent_name'].apply(
    lambda x: x.split()[0][0] + ". " + x.split()[1] if isinstance(x, str) else np.NAN
)

# %%
data_123 = pd.concat([data_12, data3])

# %%
orders_data = pd.read_csv('/orders.csv', index_col=0)
orders_data.head()
# Out:
#                                      Id   order_date_time Customer_City  \
# 0  53465d50-a568-48a9-b96e-ee2a0524fee8  14/08/2023 18:54     NEW DELHI
# 1  57d64c28-e3dc-49bd-8e8a-8e24572c6b59  30/07/2023 21:43       HAJIPUR
# 2  55d4e1bb-e148-437f-aa83-3bfbae939155  10/07/2023 21:20     HYDERABAD
# 3  509803e9-4c15-4db4-bbe7-fc1e12b6c6cc  08/08/2023 16:40        JASPUR
# 4  5cfbe41f-ffcc-4fcf-8520-94bb61dee14e  07/08/2023 08:29       JHAJJAR
#
#               Product_category  Item_price
# 0  Books & General merchandise       144.0
# 1                         Home       445.0
# 2                    LifeStyle       399.0
# 3                       Mobile     32999.0
# 4                  Electronics      1499.0

# %%
orders_data = orders_data.rename(columns={
    'Id': 'Order_id',
})

# %%
data_with_orders = data_123.merge(orders_data, on='Order_id', how='left')
data_with_orders.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/google/colab/_dataframe_summarizer.py:88: UserWarning: Parsing dates in %d/%m/%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   cast_date_col = pd.to_datetime(column, errors="coerce")
#                                      Id  Channel category  \
# 0  8c910188-c387-4a1b-8d90-24379ec8c047  Inbound  Returns
# 1  99d5ee06-8d2a-4754-bd17-ed235c70bf33  Inbound  Returns
# 2  336020c5-dc97-488f-8f16-ed33ed04e5fc  Inbound  Returns
# 3  22c5643c-3d54-487c-8863-c57e198a70be  Inbound  Returns
# 4  abd330a8-f3e2-4b7a-b14a-4ed35c4ec023  Inbound  Returns
#
#              Sub-category                                   Customer Remarks  \
# 0  Reverse Pickup Enquiry                                        Very happy
# 1          Return request       Thoda jalfi replacement approve kijiye mera
# 2                 Damaged  Technician not visit the RO and without visit ...
# 3         Fraudulent User    madam ne mera problem solve kar Diya hai . t...
# 4         Fraudulent User                             Gjjjzjxgxteuhxgxe5xhxh
#
#                                Order_id Issue_reported_Date  \
# 0                                   NaN 2023-08-04 19:10:00
# 1  89e6448f-9a48-4892-a09c-b47e0d8a87fe 2023-08-18 09:11:00
# 2  15476f9a-35cc-4f33-ae33-8d9cd6ecb1a6 2023-08-22 07:15:00
# 3                                   NaN 2023-08-14 09:21:00
# 4                                   NaN 2023-08-03 08:18:00
#
#   Issue_responded_Date Survey_response_Date    Agent_name  CSAT Score  \
# 0  2023-08-04 19:13:00           2023-08-04  J. Blackwell           1
# 1  2023-08-18 09:18:00           2023-08-18     M. Wilson           4
# 2  2023-08-22 08:15:00           2023-08-22      A. Smith           5
# 3  2023-08-14 09:27:00           2023-08-14      A. Berry           5
# 4  2023-08-03 08:23:00           2023-08-03     S. Taylor           5
#
#     order_date_time Customer_City Product_category  Item_price
# 0               NaN           NaN              NaN         NaN
# 1  14/08/2023 00:42      NAYAGARH      Electronics      1499.0
# 2               NaN           NaN              NaN         NaN
# 3               NaN           NaN              NaN         NaN
# 4               NaN           NaN              NaN         NaN

# %%
sns.heatmap(data_with_orders.isnull(), yticklabels=False, cbar=False)
# Out:
# <Axes: >

# %%
agent_data = pd.read_csv("/agents.csv", index_col=0)
agent_data.head()
# Out:
#               Agent      Supervisor          Manager    Tenure Bucket    Shift
# 0     Aaron Edwards       Mia Patel       Emily Chen            61-90  Evening
# 1      Aaron Romero     Mason Gupta  Jennifer Nguyen  On Job Training  Morning
# 2  Abigail Gonzalez      Jacob Sato  Jennifer Nguyen  On Job Training  Morning
# 3      Adam Barnett  Abigail Suzuki  Jennifer Nguyen  On Job Training  Morning
# 4      Adam Hammond   Olivia Suzuki       John Smith            31-60  Morning

# %%
agent_data.groupby(['Agent']).agg('count').head(20)
# Out:
#                     Supervisor  Manager  Tenure Bucket  Shift
# Agent
# Aaron Edwards                1        1              1      1
# Aaron Romero                 1        1              1      1
# Abigail Gonzalez             1        1              1      1
# Adam Barnett                 1        1              1      1
# Adam Hammond                 1        1              1      1
# Adam Henderson               1        1              1      1
# Adam Hernandez               1        1              1      1
# Adam Schwartz                1        1              1      1
# Adam Torres                  1        1              1      1
# Adrian Branch                1        1              1      1
# Adrian Johnson               1        1              1      1
# Adrian Richards              1        1              1      1
# Adriana Adams                1        1              1      1
# Alan Cruz                    1        1              1      1
# Alan Davies                  1        1              1      1
# Alan Sweeney                 1        1              1      1
# Albert Thornton              1        1              1      1
# Alexa Mcpherson              1        1              1      1
# Alexander Marshall           1        1              1      1
# Alexander Mata               1        1              1      1

# %%
agent_data['Agent_name'] = agent_data['Agent'].apply(
    lambda x: x.split()[0][0] + ". " + x.split()[1] if isinstance(x, str) else np.NAN
)

# %%
agent_data.groupby(['Agent_name']).agg('first').head(20)
# Out:
#                         Agent        Supervisor          Manager  \
# Agent_name
# A. Adams        Adriana Adams       Sophia Sato       John Smith
# A. Aguilar     Andrew Aguilar      Nathan Patel       Emily Chen
# A. Barnett       Adam Barnett    Abigail Suzuki  Jennifer Nguyen
# A. Barrett     Andrew Barrett  Elijah Yamaguchi       John Smith
# A. Barron    Alexandra Barron    Austin Johnson  Jennifer Nguyen
# A. Beck           Andrea Beck     Evelyn Kimura  Jennifer Nguyen
# A. Bell              Amy Bell         Wyatt Kim  Jennifer Nguyen
# A. Benjamin   Amanda Benjamin     Amelia Tanaka       Emily Chen
# A. Berry            Amy Berry  Elijah Yamaguchi       John Smith
# A. Booker    Angela Booker MD       Carter Park  Jennifer Nguyen
# A. Booth        Anthony Booth      William Park       John Smith
# A. Bowen        Anthony Bowen     Olivia Suzuki  Jennifer Nguyen
# A. Bowers        Allen Bowers       Olivia Wang       John Smith
# A. Branch       Adrian Branch       Carter Park  Jennifer Nguyen
# A. Brown         Amanda Brown   Emily Yamashita       John Smith
# A. Burke            Amy Burke       Sophia Chen      William Kim
# A. Burton       Alicia Burton         Mia Patel       Emily Chen
# A. Calderon      Amy Calderon  Elijah Yamaguchi      Michael Lee
# A. Campbell   Alexis Campbell  Elijah Yamaguchi      Michael Lee
# A. Campos       Alisha Campos        Jacob Sato       Emily Chen
#
#                Tenure Bucket      Shift
# Agent_name
# A. Adams                0-30    Morning
# A. Aguilar   On Job Training    Evening
# A. Barnett   On Job Training    Morning
# A. Barrett               >90    Evening
# A. Barron    On Job Training    Evening
# A. Beck      On Job Training    Evening
# A. Bell      On Job Training    Evening
# A. Benjamin              >90    Morning
# A. Berry                 >90    Evening
# A. Booker    On Job Training    Evening
# A. Booth               31-60    Morning
# A. Bowen     On Job Training    Morning
# A. Bowers                >90    Evening
# A. Branch    On Job Training    Morning
# A. Brown                 >90    Morning
# A. Burke     On Job Training    Morning
# A. Burton               0-30    Evening
# A. Calderon            31-60  Afternoon
# A. Campbell              >90  Afternoon
# A. Campos               0-30    Evening

# %%
data_123.groupby(['Agent_name']).agg('count').head(20)
# Out:
#               Id  Channel  category  Sub-category  Customer Remarks  Order_id  \
# Agent_name
# A. Adams     215      215       215           215                70       175
# A. Aguilar    31       31        31            31                11        19
# A. Barnett    56       56        56            56                22        41
# A. Barrett    50       50        50            50                16        35
# A. Barron     25       25        25            25                 9        18
# A. Beck       70       70        70            70                17        51
# A. Bell       20       20        20            20                10        18
# A. Benjamin   64       64        64            64                22        48
# A. Berry     135      135       135           135                62        89
# A. Booker     21       21        21            21                 3        19
# A. Booth     177      177       177           177                60       133
# A. Bowen      26       26        26            26                 5        24
# A. Bowers    126      126       126           126                35       101
# A. Branch     43       43        43            43                19        40
# A. Brown     197      197       197           197                55       155
# A. Burke      80       80        80            80                28        69
# A. Burton     29       29        29            29                 9        24
# A. Calderon   36       36        36            36                13        29
# A. Campbell  117      117       117           117                40        91
# A. Campos     95       95        95            95                31        75
#
#              Issue_reported_Date  Issue_responded_Date  Survey_response_Date  \
# Agent_name
# A. Adams                     215                   215                   215
# A. Aguilar                    31                    31                    31
# A. Barnett                    56                    56                    56
# A. Barrett                    50                    50                    50
# A. Barron                     25                    25                    25
# A. Beck                       70                    70                    70
# A. Bell                       20                    20                    20
# A. Benjamin                   64                    64                    64
# A. Berry                     135                   135                   135
# A. Booker                     21                    21                    21
# A. Booth                     177                   177                   177
# A. Bowen                      26                    26                    26
# A. Bowers                    126                   126                   126
# A. Branch                     43                    43                    43
# A. Brown                     197                   197                   197
# A. Burke                      80                    80                    80
# A. Burton                     29                    29                    29
# A. Calderon                   36                    36                    36
# A. Campbell                  117                   117                   117
# A. Campos                     95                    95                    95
#
#              CSAT Score
# Agent_name
# A. Adams            215
# A. Aguilar           31
# A. Barnett           56
# A. Barrett           50
# A. Barron            25
# A. Beck              70
# A. Bell              20
# A. Benjamin          64
# A. Berry            135
# A. Booker            21
# A. Booth            177
# A. Bowen             26
# A. Bowers           126
# A. Branch            43
# A. Brown            197
# A. Burke             80
# A. Burton            29
# A. Calderon          36
# A. Campbell         117
# A. Campos            95

# %%
data_with_agents = data_with_orders.join(agent_data, rsuffix='_1', how='left')
data_with_agents.head()
# Out:
#                                      Id  Channel category  \
# 0  8c910188-c387-4a1b-8d90-24379ec8c047  Inbound  Returns
# 1  99d5ee06-8d2a-4754-bd17-ed235c70bf33  Inbound  Returns
# 2  336020c5-dc97-488f-8f16-ed33ed04e5fc  Inbound  Returns
# 3  22c5643c-3d54-487c-8863-c57e198a70be  Inbound  Returns
# 4  abd330a8-f3e2-4b7a-b14a-4ed35c4ec023  Inbound  Returns
#
#              Sub-category                                   Customer Remarks  \
# 0  Reverse Pickup Enquiry                                        Very happy
# 1          Return request       Thoda jalfi replacement approve kijiye mera
# 2                 Damaged  Technician not visit the RO and without visit ...
# 3         Fraudulent User    madam ne mera problem solve kar Diya hai . t...
# 4         Fraudulent User                             Gjjjzjxgxteuhxgxe5xhxh
#
#                                Order_id Issue_reported_Date  \
# 0                                   NaN 2023-08-04 19:10:00
# 1  89e6448f-9a48-4892-a09c-b47e0d8a87fe 2023-08-18 09:11:00
# 2  15476f9a-35cc-4f33-ae33-8d9cd6ecb1a6 2023-08-22 07:15:00
# 3                                   NaN 2023-08-14 09:21:00
# 4                                   NaN 2023-08-03 08:18:00
#
#   Issue_responded_Date Survey_response_Date    Agent_name  ...  \
# 0  2023-08-04 19:13:00           2023-08-04  J. Blackwell  ...
# 1  2023-08-18 09:18:00           2023-08-18     M. Wilson  ...
# 2  2023-08-22 08:15:00           2023-08-22      A. Smith  ...
# 3  2023-08-14 09:27:00           2023-08-14      A. Berry  ...
# 4  2023-08-03 08:23:00           2023-08-03     S. Taylor  ...
#
#     order_date_time Customer_City Product_category Item_price  \
# 0               NaN           NaN              NaN        NaN
# 1  14/08/2023 00:42      NAYAGARH      Electronics     1499.0
# 2               NaN           NaN              NaN        NaN
# 3               NaN           NaN              NaN        NaN
# 4               NaN           NaN              NaN        NaN
#
#               Agent      Supervisor          Manager    Tenure Bucket  \
# 0     Aaron Edwards       Mia Patel       Emily Chen            61-90
# 1      Aaron Romero     Mason Gupta  Jennifer Nguyen  On Job Training
# 2  Abigail Gonzalez      Jacob Sato  Jennifer Nguyen  On Job Training
# 3      Adam Barnett  Abigail Suzuki  Jennifer Nguyen  On Job Training
# 4      Adam Hammond   Olivia Suzuki       John Smith            31-60
#
#      Shift Agent_name_1
# 0  Evening   A. Edwards
# 1  Morning    A. Romero
# 2  Morning  A. Gonzalez
# 3  Morning   A. Barnett
# 4  Morning   A. Hammond
#
# [5 rows x 21 columns]

# %%
sns.heatmap(data_with_agents.isnull(), yticklabels=False, cbar=False)
# Out:
# <Axes: >

# %%
data_with_agents = data_with_orders.merge(agent_data, how='left', on='Agent_name', copy=False)
data_with_agents.head()
# Out:
#                                      Id  Channel category  \
# 0  8c910188-c387-4a1b-8d90-24379ec8c047  Inbound  Returns
# 1  99d5ee06-8d2a-4754-bd17-ed235c70bf33  Inbound  Returns
# 2  336020c5-dc97-488f-8f16-ed33ed04e5fc  Inbound  Returns
# 3  22c5643c-3d54-487c-8863-c57e198a70be  Inbound  Returns
# 4  abd330a8-f3e2-4b7a-b14a-4ed35c4ec023  Inbound  Returns
#
#              Sub-category                                   Customer Remarks  \
# 0  Reverse Pickup Enquiry                                        Very happy
# 1          Return request       Thoda jalfi replacement approve kijiye mera
# 2                 Damaged  Technician not visit the RO and without visit ...
# 3         Fraudulent User    madam ne mera problem solve kar Diya hai . t...
# 4         Fraudulent User                             Gjjjzjxgxteuhxgxe5xhxh
#
#                                Order_id Issue_reported_Date  \
# 0                                   NaN 2023-08-04 19:10:00
# 1  89e6448f-9a48-4892-a09c-b47e0d8a87fe 2023-08-18 09:11:00
# 2  15476f9a-35cc-4f33-ae33-8d9cd6ecb1a6 2023-08-22 07:15:00
# 3                                   NaN 2023-08-14 09:21:00
# 4                                   NaN 2023-08-03 08:18:00
#
#   Issue_responded_Date Survey_response_Date    Agent_name  CSAT Score  \
# 0  2023-08-04 19:13:00           2023-08-04  J. Blackwell           1
# 1  2023-08-18 09:18:00           2023-08-18     M. Wilson           4
# 2  2023-08-22 08:15:00           2023-08-22      A. Smith           5
# 3  2023-08-14 09:27:00           2023-08-14      A. Berry           5
# 4  2023-08-03 08:23:00           2023-08-03     S. Taylor           5
#
#     order_date_time Customer_City Product_category  Item_price  \
# 0               NaN           NaN              NaN         NaN
# 1  14/08/2023 00:42      NAYAGARH      Electronics      1499.0
# 2               NaN           NaN              NaN         NaN
# 3               NaN           NaN              NaN         NaN
# 4               NaN           NaN              NaN         NaN
#
#              Agent        Supervisor          Manager    Tenure Bucket  \
# 0  James Blackwell      Jackson Park      William Kim  On Job Training
# 1      Mark Wilson     Scarlett Chen       John Smith             0-30
# 2    Anthony Smith         Mia Patel       John Smith              >90
# 3        Amy Berry  Elijah Yamaguchi       John Smith              >90
# 4     Sarah Taylor       Carter Park  Jennifer Nguyen  On Job Training
#
#      Shift
# 0  Evening
# 1  Morning
# 2  Morning
# 3  Evening
# 4  Morning

# %%
sns.heatmap(data_with_agents.isnull(), yticklabels=False, cbar=False)
# Out:
# <Axes: >

# %%
data_with_agent_numbers = data_with_orders.merge(agent_data.Agent_name.value_counts(), how='left', left_on='Agent_name', right_index=True)

# %% [markdown]
# # При выполнении вертикального объединения убедитесь в отсутствии дубликатов данных.

# %%
print(data_12.shape[0])
data_12.drop_duplicates().shape[0]
# Out:
# 72764
# 72764

# %% [markdown]
# дубликатов нет

# %% [markdown]
# #При выполнении третьего задания убедитесь более явно, что обильное количество пропущенных значений не является ошибкой объединения. Проведите больше, чем одну точечную проверку.

# %%
# 3 есть значения, для 1, 2 пустые
for el in ['a5464619-b2d8-49de-9346-5e5db0972756', '22c5643c-3d54-487c-8863-c57e198a70be', '57d64c28-e3dc-49bd-8e8a-8e24572c6b59']:
    display(orders_data[orders_data.Order_id == el])
# Out:
# Empty DataFrame
# Columns: [Order_id, order_date_time, Customer_City, Product_category, Item_price]
# Index: []
# Empty DataFrame
# Columns: [Order_id, order_date_time, Customer_City, Product_category, Item_price]
# Index: []
#                                    Order_id   order_date_time Customer_City  \
# 1      57d64c28-e3dc-49bd-8e8a-8e24572c6b59  30/07/2023 21:43       HAJIPUR
# 29042  57d64c28-e3dc-49bd-8e8a-8e24572c6b59  30/07/2023 21:43       HAJIPUR
#
#       Product_category  Item_price
# 1                 Home       445.0
# 29042             Home       445.0

# %% [markdown]
# ## При выполнении третьего задания попробуйте использовать разные виды соединений. Как это отражается на структуре датасета?

# %%
for el in ['left', 'right', 'outer', 'inner']:
    data_with_orders = data_123.merge(orders_data, on='Order_id', how=el)
    print(f"\n\n---------------------------------------------------------------------------------------------\ntype={el}   len={data_with_orders.shape[0]}")
    display(data_with_orders.head())
# Out:
# ---------------------------------------------------------------------------------------------
# type=left   len=85907
# /usr/local/lib/python3.10/dist-packages/google/colab/_dataframe_summarizer.py:88: UserWarning: Parsing dates in %d/%m/%Y %H:%M format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   cast_date_col = pd.to_datetime(column, errors="coerce")
#                                      Id  Channel category  \
# 0  8c910188-c387-4a1b-8d90-24379ec8c047  Inbound  Returns
# 1  99d5ee06-8d2a-4754-bd17-ed235c70bf33  Inbound  Returns
# 2  336020c5-dc97-488f-8f16-ed33ed04e5fc  Inbound  Returns
# 3  22c5643c-3d54-487c-8863-c57e198a70be  Inbound  Returns
# 4  abd330a8-f3e2-4b7a-b14a-4ed35c4ec023  Inbound  Returns
#
#              Sub-category                                   Customer Remarks  \
# 0  Reverse Pickup Enquiry                                        Very happy
# 1          Return request       Thoda jalfi replacement approve kijiye mera
# 2                 Damaged  Technician not visit the RO and without visit ...
# 3         Fraudulent User    madam ne mera problem solve kar Diya hai . t...
# 4         Fraudulent User                             Gjjjzjxgxteuhxgxe5xhxh
#
#                                Order_id Issue_reported_Date  \
# 0                                   NaN 2023-08-04 19:10:00
# 1  89e6448f-9a48-4892-a09c-b47e0d8a87fe 2023-08-18 09:11:00
# 2  15476f9a-35cc-4f33-ae33-8d9cd6ecb1a6 2023-08-22 07:15:00
# 3                                   NaN 2023-08-14 09:21:00
# 4                                   NaN 2023-08-03 08:18:00
#
#   Issue_responded_Date Survey_response_Date    Agent_name  CSAT Score  \
# 0  2023-08-04 19:13:00           2023-08-04  J. Blackwell           1
# 1  2023-08-18 09:18:00           2023-08-18     M. Wilson           4
# 2  2023-08-22 08:15:00           2023-08-22      A. Smith           5
# 3  2023-08-14 09:27:00           2023-08-14      A. Berry           5
# 4  2023-08-03 08:23:00           2023-08-03     S. Taylor           5
#
#     order_date_time Customer_City Product_category  Item_price
# 0               NaN           NaN              NaN         NaN
# 1  14/08/2023 00:42      NAYAGARH      Electronics      1499.0
# 2               NaN           NaN              NaN         NaN
# 3               NaN           NaN              NaN         NaN
# 4               NaN           NaN              NaN         NaN
# ---------------------------------------------------------------------------------------------
# type=right   len=86070
#     Id Channel category Sub-category Customer Remarks  \
# 0  NaN     NaN      NaN          NaN              NaN
# 1  NaN     NaN      NaN          NaN              NaN
# 2  NaN     NaN      NaN          NaN              NaN
# 3  NaN     NaN      NaN          NaN              NaN
# 4  NaN     NaN      NaN          NaN              NaN
#
#                                Order_id Issue_reported_Date  \
# 0  53465d50-a568-48a9-b96e-ee2a0524fee8                 NaT
# 1  57d64c28-e3dc-49bd-8e8a-8e24572c6b59                 NaT
# 2  55d4e1bb-e148-437f-aa83-3bfbae939155                 NaT
# 3  509803e9-4c15-4db4-bbe7-fc1e12b6c6cc                 NaT
# 4  5cfbe41f-ffcc-4fcf-8520-94bb61dee14e                 NaT
#
#   Issue_responded_Date Survey_response_Date Agent_name  CSAT Score  \
# 0                  NaT                  NaT        NaN         NaN
# 1                  NaT                  NaT        NaN         NaN
# 2                  NaT                  NaT        NaN         NaN
# 3                  NaT                  NaT        NaN         NaN
# 4                  NaT                  NaT        NaN         NaN
#
#     order_date_time Customer_City             Product_category  Item_price
# 0  14/08/2023 18:54     NEW DELHI  Books & General merchandise       144.0
# 1  30/07/2023 21:43       HAJIPUR                         Home       445.0
# 2  10/07/2023 21:20     HYDERABAD                    LifeStyle       399.0
# 3  08/08/2023 16:40        JASPUR                       Mobile     32999.0
# 4  07/08/2023 08:29       JHAJJAR                  Electronics      1499.0
# ---------------------------------------------------------------------------------------------
# type=outer   len=155026
#                                      Id  Channel       category  \
# 0  8c910188-c387-4a1b-8d90-24379ec8c047  Inbound        Returns
# 1  22c5643c-3d54-487c-8863-c57e198a70be  Inbound        Returns
# 2  abd330a8-f3e2-4b7a-b14a-4ed35c4ec023  Inbound        Returns
# 3  fba1631d-e5c9-4b85-86e7-e5417b4ffee4  Inbound  Order Related
# 4  d9b841f5-a306-4775-bc77-f1e2d64312a0  Inbound  Order Related
#
#              Sub-category                                   Customer Remarks  \
# 0  Reverse Pickup Enquiry                                        Very happy
# 1         Fraudulent User    madam ne mera problem solve kar Diya hai . t...
# 2         Fraudulent User                             Gjjjzjxgxteuhxgxe5xhxh
# 3  Seller Cancelled Order                               Very bad experience
# 4    Order status enquiry  Sir,Regarding my order of 300g Chai seeds The ...
#
#   Order_id Issue_reported_Date Issue_responded_Date Survey_response_Date  \
# 0      NaN 2023-08-04 19:10:00  2023-08-04 19:13:00           2023-08-04
# 1      NaN 2023-08-14 09:21:00  2023-08-14 09:27:00           2023-08-14
# 2      NaN 2023-08-03 08:18:00  2023-08-03 08:23:00           2023-08-03
# 3      NaN 2023-08-04 16:29:00  2023-08-04 17:39:00           2023-08-04
# 4      NaN 2023-08-27 10:03:00  2023-08-27 17:52:00           2023-08-27
#
#      Agent_name  CSAT Score order_date_time Customer_City Product_category  \
# 0  J. Blackwell         1.0             NaN           NaN              NaN
# 1      A. Berry         5.0             NaN           NaN              NaN
# 2     S. Taylor         5.0             NaN           NaN              NaN
# 3      T. Young         1.0             NaN           NaN              NaN
# 4      B. Nunez         1.0             NaN           NaN              NaN
#
#    Item_price
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ---------------------------------------------------------------------------------------------
# type=inner   len=16951
#                                      Id  Channel       category  \
# 0  99d5ee06-8d2a-4754-bd17-ed235c70bf33  Inbound        Returns
# 1  9a9432e9-948b-4eaa-86fc-4c2ccb877fd0  Inbound  Order Related
# 2  406d7a47-7dc6-4504-be9b-5ff044a7bb3a  Inbound  Order Related
# 3  a4365adc-b4cb-4de6-9a6d-9ca56d07030b  Inbound  Order Related
# 4  edddcc47-a99c-4fa2-8c36-3acb1361a98e  Inbound  Order Related
#
#            Sub-category                                   Customer Remarks  \
# 0        Return request       Thoda jalfi replacement approve kijiye mera
# 1  Order status enquiry                                               Best
# 2               Delayed  Change your delivery partner to some responsible
# 3               Delayed                                      Great effort
# 4     Priority delivery  Shopzilla customer care service was very good ...
#
#                                Order_id Issue_reported_Date  \
# 0  89e6448f-9a48-4892-a09c-b47e0d8a87fe 2023-08-18 09:11:00
# 1  b922ec6e-d3d2-4522-be34-d8c89e45f4c4 2023-08-26 07:49:00
# 2  045e5c18-1211-4d5e-a7cd-c2af955c80d6 2023-08-24 14:55:00
# 3  96db2a63-2d31-4a54-af49-d02dcc9efab0 2023-08-09 08:47:00
# 4  15fe6fa0-07d1-4568-a78e-bb5760771d1e 2023-08-11 21:45:00
#
#   Issue_responded_Date Survey_response_Date   Agent_name  CSAT Score  \
# 0  2023-08-18 09:18:00           2023-08-18    M. Wilson           4
# 1  2023-08-26 07:57:00           2023-08-26     D. Perez           5
# 2  2023-08-25 14:20:00           2023-08-25     S. Huber           1
# 3  2023-08-09 12:20:00           2023-08-09    J. Gibson           5
# 4  2023-08-11 21:48:00           2023-08-11  C. Crawford           5
#
#     order_date_time Customer_City             Product_category  Item_price
# 0  14/08/2023 00:42      NAYAGARH                  Electronics      1499.0
# 1  19/08/2023 06:55      SRINAGAR                  Electronics       999.0
# 2  17/08/2023 20:55         SURAT                       Mobile     26935.0
# 3  29/07/2023 12:42       RAJOURI  Books & General merchandise       253.0
# 4  10/08/2023 11:32          BHUJ  Books & General merchandise        96.0

# %% [markdown]
# это работает как джоины в sql, при outer много строк, но при это много пустых значений

# %% [markdown]
# #Изучите документацию pandas в части описания методов merge и join.
# #Познакомьтесь с форматом представления дат strftime.
